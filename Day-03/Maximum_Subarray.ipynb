# %% [markdown]
# # Day 3: April 3rd 2020
#
# ## Maximum Subarray

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Given an integer array nums, find the contiguous subarray (containing at least one number) which has the largest sum and return its sum.

# %% [markdown]
# ### Code:

# %%
def maxSubArray(nums):
    s = 0
    maxx = nums[0]
    for i in nums:
        s += i
        if s > maxx:
            maxx = s
        if s < 0:
            s = 0
    return maxx

# %% [markdown]
# ### Testing:

# %% [markdown]
# #### Example 1:

# %%
nums = [-2,1,-3,4,-1,2,1,-5,4]
maxSubArray(nums)
# Out:
# 6

# %% [markdown]
# Input: [-2,1,-3,4,-1,2,1,-5,4]
#
# Output: 6
#
# Explanation: [4,-1,2,1] has the largest sum = 6.

# %% [markdown]
# #### Example 2:

# %%
nums = [-5,-7,-1,-9,-4]
maxSubArray(nums)
# Out:
# -1

# %% [markdown]
# Input: [-5,-7,-1,-9,-4]
#
# Output: -1
#
# Explanation: [-1] has the largest sum = -1.

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(N). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("maximum-subarray.png")
