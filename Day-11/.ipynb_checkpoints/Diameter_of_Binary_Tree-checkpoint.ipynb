# %% [markdown]
# # Day 11: April 11th 2020
#
# ## Diameter of Binary Tree

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Given a binary tree, you need to compute the length of the diameter of the tree. The diameter of a binary tree is the length of the longest path between any two nodes in a tree. This path may or may not pass through the root.

# %% [markdown]
# ### Code:

# %%
def diameterOfBinaryTree(root):
    a = 0
    def long(n):
        nonlocal a
        if not n:
            return 0
        l = long(n.left)
        r = long(n.right)
        a = max(a,l+r)
        return max(l, r)+1
    long(root)
    return a

# %% [markdown]
# ### Testing:

# %%
# To test the code make sure to install binarytree
# pip install binarytree

from binarytree import build

# %% [markdown]
# #### Example 1:

# %%
nodes = [3, 6, 8, 2, 11, None, 13] 
tree = build(nodes)
diameterOfBinaryTree(tree)
# Out:
# 4

# %% [markdown]
# Output: 4, which is the length of the path [2,6,3,8,13].
#
# Note: The length of path between two nodes is represented by the number of edges between them.

# %% [markdown]
# #### Example 2:

# %%
nodes = [1, 5, 2, 6, None, 3, 8, 9, 7] 
tree = build(nodes)
diameterOfBinaryTree(tree)
# Out:
# 5

# %% [markdown]
# Output: 4, which is the length of the path [9,6,5,1,2,3].
#
# Note: The length of path between two nodes is represented by the number of edges between them.

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(N). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("diameter-of-binary-tree.png")
