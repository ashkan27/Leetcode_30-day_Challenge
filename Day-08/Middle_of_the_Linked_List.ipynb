# %% [markdown]
# # Day 8: April 8th 2020
#
# ## Middle of the Linked List

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Given a non-empty, singly linked list with head node head, return a middle node of linked list.
#
# If there are two middle nodes, return the second middle node.

# %% [markdown]
# ### Code:

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def middleNode(self, head):
        m = head
        c = True
        while head:
            if c:
                c = False
            else:
                c = True
                m = m.next
            head = head.next
        return m

# %% [markdown]
# ### Testing:

# %% [markdown]
# The following code is used to test the code.

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None
        
class test: 
    def __init__(self):  
        self.head = None
        
    def add(self, x):
        node = ListNode(x)
        if(self.head):
            cur = self.head
            while(cur.next):
                cur = cur.next
            cur.next = node
        else:
            self.head = node
            
    def printall(self):
        d = []
        cur = self.head
        while(cur):
            d.append(cur.val)
            cur = cur.next
        print(f'Input: {d}')
        
    def middleNode(self, head):
        m = head
        c = True
        while head:
            if c:
                c = False
            else:
                c = True
                m = m.next
            head = head.next
        return m
    
    def printmid(self, m):
        d = []
        while(m):
            d.append(m.val)
            m = m.next
        print(f'Serialization: {d}')

# %% [markdown]
# #### Example 1:

# %%
t = test()
t.add(1)
t.add(2)
t.add(3)
t.add(4)
t.add(5)
t.printall()
m = t.middleNode(t.head)
print(f'Output: Middle Node is {m.val}')
t.printmid(m)

# %% [markdown]
# Input: [1,2,3,4,5]
#
# Output: Node 3 from this list (Serialization: [3,4,5])
#
# The returned node has value 3.  (The judge's serialization of this node is [3,4,5]).
# Note that we returned a ListNode object ans, such that:
# ans.val = 3, ans.next.val = 4, ans.next.next.val = 5, and ans.next.next.next = NULL.

# %% [markdown]
# #### Example 2:

# %%
t = test()
t.add(2)
t.add(8)
t.add(3)
t.add(6)
t.add(7)
t.add(4)
t.printall()
m = t.middleNode(t.head)
print(f'Output: Middle Node is {m.val}')
t.printmid(m)
# Out:
# Input: [2, 8, 3, 6, 7, 4]
# Output: Middle Node is 6
# Serialization: [6, 7, 4]

# %% [markdown]
# Input: [2,8,3,6,7,4]
#
# Output: Node 6 from this list (Serialization: [6,7,4])
#
# The returned node has value 6. (The judge's serialization of this node is [6,7,4]). Note that we returned a ListNode object ans, such that: ans.val = 6, ans.next.val = 7, ans.next.next.val = 4, and ans.next.next.next = NULL.

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(N). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("middle-of-the-linked-list.png")
