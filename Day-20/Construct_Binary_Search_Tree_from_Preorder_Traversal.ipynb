# %% [markdown]
# # Day 20: April 20th 2020
#
# ## Construct Binary Search Tree from Preorder Traversal

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Return the root node of a binary search tree that matches the given preorder traversal.
#
# (Recall that a binary search tree is a binary tree where for every node, any descendant of node.left has a value < node.val, and any descendant of node.right has a value > node.val.  Also recall that a preorder traversal displays the value of the node first, then traverses node.left, then traverses node.right.)
#
# Note:
#
# 1 <= preorder.length <= 100
#
# The values of preorder are distinct.

# %% [markdown]
# ### Code:

# %%
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    def bstFromPreorder(self, preorder):
        n = len(preorder)
        if n == 0:
            return None
        root = TreeNode(preorder[0])
        i = 1
        for i in range(1,n+1):
            if i == n:
                break
            if root.val < preorder[i]:
                break
        root.left = self.bstFromPreorder(preorder[1:i])
        root.right = self.bstFromPreorder(preorder[i:])
        return root

# %% [markdown]
# ### Testing:

# %% [markdown]
# The following code is used to test the code.

# %%
class TreeNode:
    def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class test: 
    def __init__(self):  
        self.root = None
        
    def bstFromPreorder(self, preorder):
        n = len(preorder)
        if n == 0:
            return None
        root = TreeNode(preorder[0])
        i = 1
        for i in range(1,n+1):
            if i == n:
                break
            if root.val < preorder[i]:
                break
        root.left = self.bstFromPreorder(preorder[1:i])
        root.right = self.bstFromPreorder(preorder[i:])
        return root
    
    def printLevelOrder(self, root): 
        q = [] 
        q.append(root) 
        p = []
        while q: 
            if q[0]:
                p.append(q[0].val)
            else:
                p.append(None)
            node = q.pop(0) 
            if node:       
                if node.left or node.right:
                    if node.left: 
                        q.append(node.left) 
                    else:
                        q.append(None)
                    if node.right: 
                        q.append(node.right)
                    else:
                        q.append(None)
        return p

# %%
# To test the code make sure to install binarytree
# pip install binarytree

from binarytree import build

# %% [markdown]
# #### Example 1:

# %%
t = test()
preorder = [8,5,1,7,10,12]
nodes = t.printLevelOrder(t.bstFromPreorder(preorder))
print(nodes)
tree = build(nodes)
print(tree)
# Out:
# [8, 5, 10, 1, 7, None, 12]
#
#     __8
#    /   \
#   5     10
#  / \      \
# 1   7      12

# %% [markdown]
# #### Example 2:

# %%
t = test()
preorder = [21,19,6,1,7,20,43,42]
nodes = t.printLevelOrder(t.bstFromPreorder(preorder))
print(nodes)
tree = build(nodes)
print(tree)
# Out:
# [21, 19, 43, 6, 20, 42, None, 1, 7]
#
#         ____21___
#        /         \
#     __19         _43
#    /    \       /
#   6      20    42
#  / \
# 1   7

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(N). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("construct-binary-search-tree-from-preorder-traversal.png")
