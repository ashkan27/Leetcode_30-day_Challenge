# %% [markdown]
# # Day 26: April 26th 2020
#
# ## Longest Common Subsequence

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Given two strings text1 and text2, return the length of their longest common subsequence.
#
# A subsequence of a string is a new string generated from the original string with some characters(can be none) deleted without changing the relative order of the remaining characters. (eg, "ace" is a subsequence of "abcde" while "aec" is not). A common subsequence of two strings is a subsequence that is common to both strings.
#
# If there is no common subsequence, return 0.

# %% [markdown]
# ### Code:

# %%
def longestCommonSubsequence(text1, text2):
    n = len(text1)
    m = len(text2)
    mapp = [0]*(m+1)
    for i in range(n):
        a = mapp[0]
        for j in range(m):
            t = mapp[j+1]
            if text1[i] == text2[j]:
                mapp[j+1] = a + 1
            else:
                if mapp[j] > mapp[j+1]:
                    mapp[j+1] = mapp[j]
            a = t
    return mapp[-1]

# %% [markdown]
# ### Testing:

# %% [markdown]
# #### Example 1:

# %%
text1 = "abcde"
text2 = "ace"
longestCommonSubsequence(text1, text2)
# Out:
# 3

# %% [markdown]
# Input: text1 = "abcde", text2 = "ace"
#
# Output: 3
#
# Explanation: The longest common subsequence is "ace" and its length is 3.

# %% [markdown]
# #### Example 2:

# %%
text1 = "abc"
text2 = "def"
longestCommonSubsequence(text1, text2)
# Out:
# 0

# %% [markdown]
# Input: text1 = "abc", text2 = "def"
#
# Output: 0
#
# Explanation: There is no such common subsequence, so the result is 0.

# %% [markdown]
# #### Example 3:

# %%
text1 = "aaawsrtqarsaaryas"
text2 = "sshaassaasersyaxis"
longestCommonSubsequence(text1, text2)
# Out:
# 10

# %% [markdown]
# Input: text1 = "aaawsrtqarsaaryas", text2 = "sshaassaasersyaxis"
#
# Output: 10
#
# Explanation: The longest common subsequence is "aassaaryas" and its length is 10.

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(nm). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("longest-common-subsequence.png")
