# %% [markdown]
# # Day 23: April 23rd 2020
#
# ## Bitwise AND of Numbers Range

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Given a range [m, n] where 0 <= m <= n <= 2147483647, return the bitwise AND of all numbers in this range, inclusive.

# %% [markdown]
# ### Code:

# %%
from math import floor, log
def rangeBitwiseAnd(m, n):
    ans = 0
    while m != 0:
        if floor(log(m,2)) != floor(log(n,2)):
            break
        x = pow(2,floor(log(n,2)))
        ans += x
        m = m-x
        n = n-x
    return ans

# %% [markdown]
# ### Testing:

# %% [markdown]
# #### Example 1:

# %%
m = 5
n = 7
rangeBitwiseAnd(m, n)
# Out:
# 4

# %% [markdown]
# #### Example 2:

# %%
m = 3
n = 12
rangeBitwiseAnd(m, n)
# Out:
# 0

# %% [markdown]
# #### Example 3:

# %%
m = 16
n = 31
rangeBitwiseAnd(m, n)
# Out:
# 16

# %% [markdown]
# #### Example 4:

# %%
m = 20
n = 31
rangeBitwiseAnd(m, n)
# Out:
# 16

# %% [markdown]
# #### Example 5:

# %%
m = 24
n = 31
rangeBitwiseAnd(m, n)
# Out:
# 24

# %% [markdown]
# #### Example 6:

# %%
m = 25
n = 31
rangeBitwiseAnd(m, n)
# Out:
# 24

# %% [markdown]
# #### Example 7:

# %%
m = 31
n = 31
rangeBitwiseAnd(m, n)
# Out:
# 31

# %% [markdown]
# ### Evaluation:

# %% [markdown]
# The runtime complexity of this code is O(log n). Below you can see the submission details for my code.

# %%
from IPython.display import Image
Image("bitwise-and-of-numbers-range.png")
